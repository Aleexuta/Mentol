# %%
#autocorrect text

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import re 
import string
from nltk import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import pickle
from textblob import TextBlob
from textblob.en import Spelling

# %%
positive=pd.read_csv('../datasets/positive_reddit_combined.csv')
negative=pd.read_csv('../datasets/negative_reddit_combined.csv')

# %%
from autocorrect import Speller

# %%
spell = Speller(fast=True)

# %%
def correct_sentence(row):
    return spell(str(row))

# %%
positive['post']=positive['post'].apply(correct_sentence)
negative['post']=negative['post'].apply(correct_sentence)

# %%
positive
# Out:
#         Unnamed: 0     subreddit  \
# 0                0     addiction
# 1                1     addiction
# 2                2     addiction
# 3                3     addiction
# 4                4     addiction
# ...            ...           ...
# 362913      362913  suicidewatch
# 362914      362914  suicidewatch
# 362915      362915  suicidewatch
# 362916      362916  suicidewatch
# 362917      362917  suicidewatch
#
#                                                      post
# 0       decide go tramadol well never take tablet life...
# 1       vyvans addict get pretty bad yesterday go with...
# 2       quit coke nicotine im gon na start say ive rea...
# 3       ok lead drug addict love mani detail gf little...
# 4       brother problem im weed think much anyth cant ...
# ...                                                   ...
# 362913  not make want live know ill never want im tota...
# 362914   fix hair  go kill hair extreme mat month depr...
# ...

# %%
negative
# Out:
#         Unnamed: 0                                               post  \
# 0                0  neither obama hillary tweet new year greet tod...
# 1                1  scott shane nation secure report new york time...
# 2                2  list favorite people listen robert david steel...
# 3                3  tumor user admit get vibrant gamepad get upvot...
# 4                4  freeway crack system brilliant documentary exp...
# ...            ...                                                ...
# 634484      634484  intern academy confer edu teach learn intern a...
# 634485      634485  suck dont want daughter start first teach job ...
# 634486      634486  teacher leave school mid year worth shit get h...
# 634487      634487  time best teacher time best teacher let learn ...
# 634488      634488  bomb first observe vent final happen first obs...
#
#         subreddit
# 0       nonmental
# 1       nonmental
# 2       nonmental
# 3       nonmental
# 4       nonmental
# ...

# %%
positive.to_csv('../datasets/positive_reddit_combined.csv', index=False)
negative.to_csv('../datasets/negative_reddit_combined.csv', index=False)
